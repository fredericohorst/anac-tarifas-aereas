# %% [markdown]
# # Análise de Séries Históricas de Tarifas Aéreas
#
# #### Frederico Horst
#
# Fontes dos Dados:
# - Séries históricas de tarifas aéreas, por origem, destino e empresa: disponível no site da ANAC em:
# https://sistemas.anac.gov.br/sas/downloads/view/frmDownload.aspx
# - Série histórica do IPCA: disponível no site do IBGE em:
# https://www.ibge.gov.br/estatisticas/economicas/precos-e-custos/9256-indice-nacional-de-precos-ao-consumidor-amplo.html?=&t=series-historicas
#
# Mais informações sobre o tarifário:
# https://www.anac.gov.br/assuntos/dados-e-estatisticas/mercado-do-transporte-aereo

# %% [markdown]
# ### Importando as séries de dados:

# %%
import os
import pandas as pd


# importando as séries de tarifas dos arquivos da ANAC:
path = 'csv_files_from_anac/'
files = os.listdir(path)

files_list = []

for file in files:
    if len(file) == 10:
        files_list.append(file)
    else:
        pass

import_data = []
# pd.DataFrame(data=None, columns=columns)

for file in files_list:
#     print(path+file)
    import_data.append(pd.read_csv(path+file, ';'))

tarifas_df = pd.concat(import_data)

# %%
# corrigindo a tarifa para float:
tarifas_df['TARIFA'] = tarifas_df.TARIFA.str.replace(',','.').astype(float)
# adicionando coluna com o período (ano + mes)
tarifas_df['PERIODO'] = tarifas_df.ANO.astype(str)+tarifas_df.MES.astype(str).str.zfill(2)
# ordenando
tarifas_df = tarifas_df.sort_values(['PERIODO'])

tarifas_df.head()
# Out:
#        ANO  MES EMPRESA ORIGEM DESTINO  TARIFA  ASSENTOS PERIODO
# 795   2002    1     RSL   SBKP    SBBH  218.00         1  200201
# 1539  2002    1     TAM   SBGR    SBCF  167.45        74  200201
# 1540  2002    1     TAM   SBVT    SBRJ  125.94        84  200201
# 1541  2002    1     TAM   SBPA    SBBR  677.79        50  200201
# 1542  2002    1     TAM   SBRF    SBGL  316.42       664  200201

# %%
periodo = bkp_tarifas_df.PERIODO.unique()

# ajustando repeticoes do dataset e salvando os arquivos ajustados:

bkp_tarifas_df = tarifas_df.copy()

for i in periodo:
    print(i)
    df = bkp_tarifas_df[bkp_tarifas_df.PERIODO == i]
    repeated_fields = df.loc[df.index.repeat(df.ASSENTOS)]
    repeated_fields.to_csv('tarifas_df_ajustada/tarifas_df' + i + '.csv')
    df = None
    repeated_fields = None
    print('tarifas_df_ajustada/tarifas_df' + i + '.csv -- saving complete')
# Out:
# 200201
# tarifas_df_ajustada/tarifas_df200201.csv -- saving complete
# 200202
# tarifas_df_ajustada/tarifas_df200202.csv -- saving complete
# 200203
# tarifas_df_ajustada/tarifas_df200203.csv -- saving complete
# 200204
# tarifas_df_ajustada/tarifas_df200204.csv -- saving complete
# 200205
# tarifas_df_ajustada/tarifas_df200205.csv -- saving complete
# 200206
# tarifas_df_ajustada/tarifas_df200206.csv -- saving complete
# 200207
# tarifas_df_ajustada/tarifas_df200207.csv -- saving complete
# 200208
# tarifas_df_ajustada/tarifas_df200208.csv -- saving complete
# 200209
# tarifas_df_ajustada/tarifas_df200209.csv -- saving complete
# 200210
# tarifas_df_ajustada/tarifas_df200210.csv -- saving complete
# 200211
# tarifas_df_ajustada/tarifas_df200211.csv -- saving complete
# 200212
# tarifas_df_ajustada/tarifas_df200212.csv -- saving complete
# 200301
# tarifas_df_ajustada/tarifas_df200301.csv -- saving complete
# 200302
# tarifas_df_ajustada/tarifas_df200302.csv -- saving complete
# ...

# %%
# importando as séries de tarifas aéreas já ajustadas:
path = 'tarifas_df_ajustada/'
files = os.listdir(path)

files_list = []

for file in files:
    if len(file) == 10:
        files_list.append(file)
    else:
        pass

import_data = []

for file in files_list:
    import_data.append(pd.read_csv(path+file, ';'))

tarifas_df = pd.concat(import_data)

# importando o dicionário de dados dos aeroportos:
# aeroportos = pd.read_csv('aeroportos.csv',';')

# importando a série histórica do IPCA:
# ipca = pd.read_csv('ipca_historico.csv',';')

# %%
tarifas_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-6d6c6e46334c> in <module>
#       2
#       3 bkp_tarifas_df = tarifas_df.copy()
# ----> 4 repeated_fields = bkp_tarifas_df.loc[bkp_tarifas_df.index.repeat(bkp_tarifas_df.ASSENTOS)]
#       5 tarifas_df = repeated_fields.copy()
#       6
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1764
#    1765             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1766             return self._getitem_axis(maybe_callable, axis=axis)
#    1767
#    1768     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1950                     raise ValueError("Cannot index with multidimensional key")
#    1951
# ...

# %%
ipca.tail()

# %%
# tarifas para entre as cidades: São Paulo, Brasília, Rio de Janeiro, Porto Alegre e Curitiba

cidades = ['São Paulo', 'Brasília', 'Rio de Janeiro', 'Porto Alegre', 'Curitiba']

aeroportos_selecionados = aeroportos[aeroportos['Cidade'].isin(cidades)]

trechos_selecionados = tarifas_df[tarifas_df['ORIGEM'].isin(aeroportos_selecionados.ICAO)]
trechos_selecionados = trechos_selecionados[trechos_selecionados['DESTINO'].isin(aeroportos_selecionados.ICAO)]


trechos_selecionados.head()

# %%
empresas = trechos_selecionados['EMPRESA'].unique()
origens = trechos_selecionados['ORIGEM'].unique()
destinos = trechos_selecionados['DESTINO'].unique()

# %%
for origem in origens:
    for destino in destinos:
        print(origem, destino)

# %%
# gráfico

df_teste = trechos_selecionados[trechos_selecionados['ORIGEM']=='SBCT'].copy()
df_teste = df_teste[df_teste['DESTINO']=='SBRJ']

df_teste_st = df_teste.groupby(['PERIODO','EMPRESA']).mean().reset_index()[['PERIODO','EMPRESA','TARIFA']]

import matplotlib.pyplot as plt
import seaborn as sns

f = plt.figure(figsize=(40,20))

# f = plt.plot(x=df_teste['periodo'], y=df_teste['tarifa'])
f = sns.scatterplot(x='PERIODO', y='TARIFA',
             hue='EMPRESA',# style="event",
             data=df_teste)

f = plt.xticks(rotation=90)

f = plt.title('Preços de Passagens de CWB para SDU - disperção \n', fontweight='bold', fontsize=14)

plt.savefig('dispercao-cwb-sdu.png')

# %%
# gráfico violino


f = plt.figure(figsize=(40,20))

# f = plt.plot(x=df_teste['periodo'], y=df_teste['tarifa'])
f = sns.violinplot(x='PERIODO', y='TARIFA',
#              hue='EMPRESA',# style="event",
             data=df_teste_st)

f = plt.xticks(rotation=90)

f = plt.title('Preços de Passagens de CWB para SDU - boxplot \n', fontweight='bold', fontsize=14)

plt.savefig('boxplot-cwb-sdu.png')

# %%
ipca.tail(50)
# Out:
#      Período   Ano  Mês  Número Índice (Dez/93 = 100)  Variação no Mês  \
# 265   201602  2016  FEV                       4591.18             0.90
# 266   201603  2016  MAR                       4610.92             0.43
# 267   201604  2016  ABR                       4639.05             0.61
# 268   201605  2016  MAI                       4675.23             0.78
# 269   201606  2016  JUN                       4691.59             0.35
# 270   201607  2016  JUL                       4715.99             0.52
# 271   201608  2016  AGO                       4736.74             0.44
# 272   201609  2016  SET                       4740.53             0.08
# 273   201610  2016  OUT                       4752.86             0.26
# 274   201611  2016  NOV                       4761.42             0.18
# 275   201612  2016  DEZ                       4775.70             0.30
# 276   201701  2017  JAN                       4793.85             0.38
# ...

# %%
empresas
# Out:
# array(['TAM', 'RSL', 'VRG', 'VSP', 'GLO', 'NES', 'ONE', 'WEB', 'BRB',
#        'TIB', 'VRN', 'NHG', 'AZU', 'PTB', 'PTN'], dtype=object)

# %%
# Out:
# SBPA SBBR
# SBPA SBRJ
# SBPA SBPA
# SBPA SBGL
# SBPA SBCT
# SBPA SBSP
# SBBR SBBR
# SBBR SBRJ
# SBBR SBPA
# SBBR SBGL
# SBBR SBCT
# SBBR SBSP
# SBGL SBBR
# SBGL SBRJ
# SBGL SBPA
# SBGL SBGL
# SBGL SBCT
# SBGL SBSP
# SBCT SBBR
# SBCT SBRJ
# SBCT SBPA
# SBCT SBGL
# SBCT SBCT
# SBCT SBSP
# SBSP SBBR
# SBSP SBRJ
# SBSP SBPA
# SBSP SBGL
# SBSP SBCT
# SBSP SBSP
# SBRJ SBBR
# SBRJ SBRJ
# SBRJ SBPA
# SBRJ SBGL
# SBRJ SBCT
# SBRJ SBSP

# %%
df_teste.describe()
# Out:
#                 ANO           MES        TARIFA      ASSENTOS
# count  70845.000000  70845.000000  70845.000000  70845.000000
# mean    2015.404870      6.770485    359.288216     18.359574
# std        2.791945      3.436335    263.705952     81.399109
# min     2002.000000      1.000000      0.490000      1.000000
# 25%     2014.000000      4.000000    173.630000      1.000000
# 50%     2016.000000      7.000000    280.900000      3.000000
# 75%     2017.000000     10.000000    461.600000      9.000000
# max     2019.000000     12.000000   3130.240000   5804.000000
